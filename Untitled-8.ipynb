# %%
import sklearn
from sklearn import datasets
import pandas as pd

# %%
boston=datasets.load_boston();

# %%
df=pd.DataFrame(data=boston.data,columns=boston.feature_names)
df['target']=boston.target

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# 2       17.8  392.83   4.03    34.7
# 3       18.7  394.63   2.94    33.4
# 4       18.7  396.90   5.33    36.2
# ..       ...     ...    ...     ...
# 501     21.0  391.99   9.67    22.4
# 502     21.0  396.90   9.08    20.6
# 503     21.0  396.90   5.64    23.9
# 504     21.0  393.45   6.48    22.0
# 505     21.0  396.90   7.88    11.9
#
# [506 rows x 14 columns]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %%
y=df.target
X=df.drop('target',axis=1)
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
model = keras.Sequential(
    [
        layers.Dense(500, activation="sigmoid"),
        layers.Dense(800, activation="sigmoid"),
        layers.Dense(4000, activation="sigmoid"),        
        layers.Dense(2000, activation="sigmoid"),
        layers.Dense(1, name="layer5"),
    ]
)
model.compile(optimizer='nadam', loss='mean_absolute_error')
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 4s 214ms/step - loss: 8.3792
# Epoch 2/100
# 12/12 [==============================] - 3s 212ms/step - loss: 6.5499
# Epoch 3/100
# 12/12 [==============================] - 3s 216ms/step - loss: 5.7652
# Epoch 4/100
# 12/12 [==============================] - 3s 212ms/step - loss: 5.6159
# Epoch 5/100
# 12/12 [==============================] - 3s 210ms/step - loss: 5.5073
# Epoch 6/100
# 12/12 [==============================] - 3s 208ms/step - loss: 5.3609
# Epoch 7/100
# 12/12 [==============================] - 3s 210ms/step - loss: 5.3062
# Epoch 8/100
# 12/12 [==============================] - 3s 209ms/step - loss: 5.1504
# Epoch 9/100
# 12/12 [==============================] - 3s 209ms/step - loss: 4.8727
# Epoch 10/100
# 12/12 [==============================] - 3s 209ms/step - loss: 4.7646
# Epoch 11/100
# 12/12 [==============================] - 3s 208ms/step - loss: 4.6730
# Epoch 12/100
# 12/12 [==============================] - 3s 209ms/step - loss: 4.6108
# Epoch 13/100
# 12/12 [==============================] - 3s 214ms/step - loss: 4.5773
# Epoch 14/100
# 12/12 [==============================] - 3s 211ms/step - loss: 4.3455
# Epoch 15/100
# 12/12 [==============================] - 3s 209ms/step - loss: 4.2459
# Epoch 16/100
# 12/12 [==============================] - 3s 209ms/step - loss: 4.1015
# Epoch 17/100
# 12/12 [==============================] - 3s 208ms/step - loss: 3.9469
# Epoch 18/100
# 12/12 [==============================] - 3s 208ms/step - loss: 3.8674
# Epoch 19/100
# 12/12 [==============================] - 3s 209ms/step - loss: 3.8244
# Epoch 20/100
# 12/12 [==============================] - 3s 208ms/step - loss: 3.7951
# Epoch 21/100
# 12/12 [==============================] - 3s 209ms/step - loss: 3.5596
# Epoch 22/100
# 12/12 [==============================] - 3s 216ms/step - loss: 3.5453
# Epoch 23/100
# 12/12 [==============================] - 3s 210ms/step - loss: 3.5649
# Epoch 24/100
# 12/12 [==============================] - 3s 211ms/step - loss: 3.2765
# Epoch 25/100
# 12/12 [==============================] - 3s 211ms/step - loss: 3.5266
# Epoch 26/100
# 12/12 [==============================] - 3s 210ms/step - loss: 3.4291
# Epoch 27/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.3666
# Epoch 28/100
# 12/12 [==============================] - 3s 208ms/step - loss: 3.3359
# Epoch 29/100
# 12/12 [==============================] - 3s 210ms/step - loss: 3.3274
# Epoch 30/100
# 12/12 [==============================] - 3s 209ms/step - loss: 3.3953
# Epoch 31/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.2747
# Epoch 32/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.1552
# Epoch 33/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.6464
# Epoch 34/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.0706
# Epoch 35/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3
# 12/12 [==============================] - 2s 207ms/step - loss: 2.4079
# Epoch 79/100
# 12/12 [==============================] - 3s 214ms/step - loss: 2.4300
# Epoch 80/100
# 12/12 [==============================] - 3s 210ms/step - loss: 2.5557
# Epoch 81/100
# 12/12 [==============================] - 3s 212ms/step - loss: 2.8993
# Epoch 82/100
# 12/12 [==============================] - 3s 218ms/step - loss: 2.5364
# Epoch 83/100
# 12/12 [==============================] - 3s 212ms/step - loss: 2.5564
# Epoch 84/100
# 12/12 [==============================] - 3s 210ms/step - loss: 2.3528
# Epoch 85/100
# 12/12 [==============================] - 3s 208ms/step - loss: 2.4574
# Epoch 86/100
# 12/12 [==============================] - 3s 210ms/step - loss: 2.5426
# Epoch 87/100
# 12/12 [==============================] - 3s 214ms/step - loss: 2.5606
# Epoch 88/100
# 12/12 [==============================] - 2s 208ms/step - loss: 2.4778
# Epoch 89/100
# 12/12 [==============================] - 3s 214ms/step - loss: 2.4610
# Epoch 90/100
# 12/12 [==============================] - 3s 213ms/step - loss: 2.4116
# Epoch 91/100
# 12/12 [==============================] - 3s 212ms/step - loss: 2.5383
# Epoch 92/100
# 12/12 [==============================] - 3s 215ms/step - loss: 2.3499
# Epoch 93/100
# 12/12 [==============================] - 3s 214ms/step - loss: 2.3682
# Epoch 94/100
# 12/12 [==============================] - 2s 207ms/step - loss: 2.2856
# Epoch 95/100
# 12/12 [==============================] - 3s 222ms/step - loss: 2.3649
# Epoch 96/100
# 12/12 [==============================] - 3s 217ms/step - loss: 2.4117
# Epoch 97/100
# 12/12 [==============================] - 3s 211ms/step - loss: 2.4600
# Epoch 98/100
# 12/12 [==============================] - 3s 223ms/step - loss: 2.5041
# Epoch 99/100
# 12/12 [==============================] - 3s 208ms/step - loss: 2.3481
# Epoch 100/100
# 12/12 [==============================] - 2s 207ms/step - loss: 2.3048

# %%
model.predict((X_test))
# Out:
# 4/4 [==============================] - 0s 10ms/step
# array([[33.387115],
#        [18.567028],
#        [27.325487],
#        [13.884718],
#        [23.921713],
#        [ 9.596116],
#        [20.50142 ],
#        [20.578794],
#        [18.49216 ],
#        [42.766323],
#        [20.143122],
#        [42.295998],
#        [21.538197],
#        [19.521177],
#        [29.290453],
#        [27.882765],
#        [11.880894],
#        [20.028212],
#        [18.910738],
#        [10.181904],
#        [21.877558],
#        [50.02129 ],
#        [20.53429 ],
#        [ 9.641679],
#        [48.828217],
#        [20.247677],
#        [22.253109],
#        [ 9.362248],
#        [20.31534 ],
#        [19.632181],
#        [44.635326],
#        [22.965387],
#        [22.892832],
#        [23.816843],
#        [18.728851],
#        [19.652143],
#        [11.990674],
#        [15.912158],
#        [20.356611],
#        [18.3719  ],
#        [24.24307 ],
#        [23.742132],
#        [12.489743],
#        [24.020952],
#        [28.030136],
#        [29.64538 ],
#        [27.145472],
#        [21.644766],
#        [26.82454 ],
#        [19.026655],
#        [21.172503],
#        [29.798862],
#        [15.171044],
#        [17.307207],
#        [19.499338],
#        [31.800396],
#        [25.536345],
#        [18.856794],
#        [22.085787],
#        [ 9.639665],
#        [23.358973],
#        [18.131647],
#        [19.329702],
#        [20.872898],
#        [32.27884 ],
#        [18.017986],
#        [31.97596 ],
#        [45.400383],
#        [17.180252],
#        [36.455627],
#        [20.039053],
#        [26.880194],
#        [19.36176 ],
#        [11.651004],
#        [21.84042 ],
#        [17.285858],
#        [35.12816 ],
#        [26.606142],
#        [13.784559],
#        [34.49002 ],
#        [33.333294],
#        [21.716671],
#        [27.025452],
#        [23.949057],
#        [27.460196],
#        [14.550225],
#        [32.363358],
#        [27.961407],
#        [16.397158],
#        [20.10768 ],
#        [17.398457],
#        [25.221857],
#        [12.926282],
#        [20.827333],
#        [19.541677],
#        [19.244776],
#        [12.998892],
#        [35.27481 ],
#        [12.072304],
#        [15.850238],
#        [14.666677],
#        [14.357526],
#        [14.282348],
#        [16.65026 ],
#        [12.40725 ],
#        [21.014507],
#        [25.876078],
#        [23.390558],
#        [40.398468],
#        [25.74066 ],
#        [17.807993],
#        [30.877163],
#        [22.417616],
#        [29.90177 ],
#        [20.265306],
#        [21.65563 ],
#        [11.460781],
#        [11.817573],
#        [36.6414  ],
#        [10.702132],
#        [28.842321],
#        [29.026688],
#        [10.183141],
#        [18.229311],
#        [17.767471],
#        [46.80626 ],
#        [17.95796 ]], dtype=float32)

# %%
y_test
# Out:
# 189    34.9
# 492    20.1
# 300    24.8
# 34     13.5
# 463    20.2
#        ...
# 378    13.1
# 367    23.1
# 113    18.7
# 368    50.0
# 361    19.9
# Name: target, Length: 127, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X_train,y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x16d5b6bc100>,
#  <matplotlib.lines.Line2D at 0x16d5b6bc1f0>,
#  <matplotlib.lines.Line2D at 0x16d5b6bc250>,
#  <matplotlib.lines.Line2D at 0x16d5b6bc3a0>,
#  <matplotlib.lines.Line2D at 0x16d5b6bc4c0>,
#  <matplotlib.lines.Line2D at 0x16d5b6bc5e0>,
#  <matplotlib.lines.Line2D at 0x16d5b6bc700>,
#  <matplotlib.lines.Line2D at 0x16d5b6bc820>,
#  <matplotlib.lines.Line2D at 0x16d5b6bc940>,
#  <matplotlib.lines.Line2D at 0x16d5b6bca60>,
#  <matplotlib.lines.Line2D at 0x16d5b676e80>,
#  <matplotlib.lines.Line2D at 0x16d5b6bcb80>,
#  <matplotlib.lines.Line2D at 0x16d5b6bcd90>]

# %%
plt.plot(X_test,y_test)
# Out:
# [<matplotlib.lines.Line2D at 0x16d11a6d040>,
#  <matplotlib.lines.Line2D at 0x16d11a6d610>,
#  <matplotlib.lines.Line2D at 0x16d11a6d100>,
#  <matplotlib.lines.Line2D at 0x16d11a6dac0>,
#  <matplotlib.lines.Line2D at 0x16d11a6dc70>,
#  <matplotlib.lines.Line2D at 0x16d11a6de80>,
#  <matplotlib.lines.Line2D at 0x16d11a6d7c0>,
#  <matplotlib.lines.Line2D at 0x16d11a6ddc0>,
#  <matplotlib.lines.Line2D at 0x16d11a6d8e0>,
#  <matplotlib.lines.Line2D at 0x16d11a6dfa0>,
#  <matplotlib.lines.Line2D at 0x16d11c5c850>,
#  <matplotlib.lines.Line2D at 0x16d11a6d760>,
#  <matplotlib.lines.Line2D at 0x16d11a5c3a0>]
